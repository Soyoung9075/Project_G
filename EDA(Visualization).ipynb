# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
font_path = 'C:/Windows/Fonts/malgun.ttf'
font = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font)

# %%
df = pd.read_csv(r'C:\Users\soyou\Dropbox\대체보고서\분양 데이터\merge\seoul_merge_ver2.csv')

# %%
df.head(1)
# Out:
#           아파트명2               아파트이름                      공급위치   공급세대  공급면적  \
# 0  서대문푸르지오센트럴파크  서대문　푸르지오　센트럴파크（서울）  서울특별시　서대문구　홍제동　５７－５번지　일대  320세대  49.5
#
#      공급금액  지역 주택구분 분양/임대      시공사  ...  전세가율_2020 전세가율_2021 전세가율_2022  \
# 0  51,020  서울   민영  분양주택  (주)대우건설  ...        NaN       NaN       NaN
#
#    전세가율_2023    소형평수비중    중형평수비중    대형평수비중      평균   특목고 진학률         상위
# 0        NaN  0.652644  0.328125  0.019231  0.7825  0.031143  39.071429
#
# [1 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '평균', '특목고 진학률', '상위'],
#       dtype='object')

# %%
df['공급금액']
# Out:
# 0       51,020
# 1       56,870
# 2       68,750
# 3       69,270
# 4       71,830
#         ...
# 479    114,780
# 480     67,200
# 481     70,300
# 482     75,800
# 483     87,300
# Name: 공급금액, Length: 484, dtype: object

# %%
# 공급금액 int 타입으로 바꾸기
df['공급금액'] = df['공급금액'].str.replace(',', '').astype(int)

# %% [markdown]
# ## 소형평수 / 대형 평수

# %% [markdown]
# ### 소형평수 비중/대형 평수 비중 - 공급금액 기준 scatter plot

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_group = df_space[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','공급금액']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
g = sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '공급금액', data = df_space_group, sizes=(40, 400), alpha=.7)
plt.title("서울 지역별 59타입 공급금액 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_group = df_space[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','공급금액']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
plot2 = sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '공급금액', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 59타입 공급금액 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 84 타입 기준
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_group = df_space[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','공급금액']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '공급금액', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 공급금액 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 84 타입 기준
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_group = df_space[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','공급금액']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '공급금액', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 공급금액 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 소형평수 비중/대형 평수 비중 - 매매가 기준 scatter plot

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','매매평균가']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '매매평균가', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 59타입 매매가 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','매매평균가']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '매매평균가', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 59타입 매매가 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','매매평균가']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '매매평균가', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 매매가 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','매매평균가']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '매매평균가', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 매매가 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 소형평수 비중/대형 평수 비중 - 매매가-분양가 기준 scatter plot

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)
df_space_copy['매매_분양가gap'] = df_space_copy['매매평균가'] - df_space_copy['공급금액']

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','매매_분양가gap']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '매매_분양가gap', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 59타입 매매가-분양가 GAP 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '59타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)
df_space_copy['매매_분양가gap'] = df_space_copy['매매평균가'] - df_space_copy['공급금액']

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','매매_분양가gap']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '매매_분양가gap', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 59타입 매매가-분양가 GAP 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)
df_space_copy['매매_분양가gap'] = df_space_copy['매매평균가'] - df_space_copy['공급금액']

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '대형평수비중','전용면적_분류','매매_분양가gap']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '대형평수비중', hue = '구', size = '매매_분양가gap', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 매매가-분양가 GAP 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_space = df.loc[df['전용면적_분류'] == '84타입']
df_space_copy = df_space.copy()
df_space_copy['매매평균가'] = df_space[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)
df_space_copy['매매_분양가gap'] = df_space_copy['매매평균가'] - df_space_copy['공급금액']

df_space_group = df_space_copy[['아파트명2', '구', '소형평수비중', '중형평수비중','전용면적_분류','매매_분양가gap']].groupby(['구', '아파트명2', '전용면적_분류']).mean().reset_index()
sns.relplot(x = '소형평수비중', y = '중형평수비중', hue = '구', size = '매매_분양가gap', data = df_space_group, sizes=(40, 400), alpha=.7, height = 5, aspect = 1)
plt.title("서울 지역별 84타입 매매가-분양가 GAP 분포")
plt.show()
# Out:
# C:\Users\soyou\anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 을지로/강남까지 걸리는 시간에 따른 분포

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중'],
#       dtype='object')

# %%
# 공급금액 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2', '을지로', '강남','전용면적_분류','공급금액']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '공급금액', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '을지로', '강남','전용면적_분류','공급금액']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '공급금액', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
fig, axe = plt.subplots(1,2, figsize=(12,5))

df_copy = df.copy()
df_copy['매매평균가'] = df[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

df_space_group_59 = df_copy.loc[df_copy['전용면적_분류'] == '59타입'][['아파트명2', '을지로', '강남','전용면적_분류','매매평균가']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '매매평균가', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df_copy.loc[df_copy['전용면적_분류'] == '84타입'][['아파트명2', '을지로', '강남','전용면적_분류','매매평균가']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '매매평균가', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
fig, axe = plt.subplots(1,2, figsize=(12,5))

df_copy = df.copy()
df_copy['매매평균가'] = df[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)
df_copy['매매_분양가gap'] = df_copy['매매평균가'] - df_copy['공급금액']

df_space_group_59 = df_copy.loc[df_copy['전용면적_분류'] == '59타입'][['아파트명2', '을지로', '강남','전용면적_분류','매매_분양가gap']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매가-분양가 GAP 분포")
df_space_group_84 = df_copy.loc[df_copy['전용면적_분류'] == '84타입'][['아파트명2', '을지로', '강남','전용면적_분류','매매_분양가gap']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '을지로', y = '강남', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매가-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 지하철 노선에 따른 아파트 가격 분포

# %% [markdown]
# 1. 지하철 노선별로 boxplot+scatterplot?
# 2. 승하차총객수_노선기준 / 승하차총객수_역기준 relplot

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중'],
#       dtype='object')

# %% [markdown]
# ### 노선별 분포

# %%
df_group_59 = df[df['전용면적_분류'] == "59타입"][['아파트명2', '전용면적_분류','호선', '공급금액']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()
df_group_84 = df[df['전용면적_분류'] == "84타입"][['아파트명2', '전용면적_분류','호선', '공급금액']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()

# %%
# 59타입 공급금액
fig, axe = plt.subplots(figsize = (15, 6))
sns.swarmplot(data = df_group_59, x = '호선', y = '공급금액', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 공금금액 분포")
plt.show()

# %%
# 84타입 공급금액
fig, axe = plt.subplots(figsize = (15, 6))
sns.swarmplot(data = df_group_84, x = '호선', y = '공급금액', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 공금금액 분포")
plt.show()

# %%
#59 공급금액
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_59, x = '호선', y = '공급금액', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '공급금액', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 공금금액 분포")
plt.show()

# %%
#84 공급금액
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_84, x = '호선', y = '공급금액', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '공급금액', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 공금금액 분포")
plt.show()

# %% [markdown]
# ### 노선별 분포 - 평균 매매가 기준

# %%
df['매매평균가'] = df[['매매_2019', '매매_2020', '매매_2021','매매_2022', '매매_2023']].mean(axis =1)

# %%
df_group_59 = df[df['전용면적_분류'] == "59타입"][['아파트명2', '전용면적_분류','호선', '매매평균가']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()
df_group_84 = df[df['전용면적_분류'] == "84타입"][['아파트명2', '전용면적_분류','호선', '매매평균가']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()

# %%
# 59타입 공급금액
fig, axe = plt.subplots(figsize = (15, 4))
sns.swarmplot(data = df_group_59, x = '호선', y = '매매평균가', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 매매평균가 분포")
plt.show()

# %%
# 84타입 공급금액
fig, axe = plt.subplots(figsize = (15, 4))
sns.swarmplot(data = df_group_84, x = '호선', y = '매매평균가', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 매매평균가 분포")
plt.show()

# %%
#59 매매평균가
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_59, x = '호선', y = '매매평균가', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '매매평균가', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 매매평균가 분포")
plt.show()

# %%
#84 매매평균가
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_84, x = '호선', y = '매매평균가', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '매매평균가', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 매매평균가 분포")
plt.show()

# %% [markdown]
# ### 매매가-분양가 gap 기준

# %%
df['매매_분양가gap'] = df['매매평균가'] - df['공급금액']

# %%
df_group_59 = df[df['전용면적_분류'] == "59타입"][['아파트명2', '전용면적_분류','호선', '매매_분양가gap']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()
df_group_84 = df[df['전용면적_분류'] == "84타입"][['아파트명2', '전용면적_분류','호선', '매매_분양가gap']].groupby(['아파트명2', '전용면적_분류', '호선']).mean().reset_index()

# %%
# 59타입 매매-분양가 GAP
fig, axe = plt.subplots(figsize = (15, 4))
sns.swarmplot(data = df_group_59, x = '호선', y = '매매_분양가gap', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 매매-분양가 GAP 분포")
plt.show()

# %%
# 84타입 매매-분양가 GAP
fig, axe = plt.subplots(figsize = (15, 4))
sns.swarmplot(data = df_group_84, x = '호선', y = '매매_분양가gap', hue = '아파트명2', palette = "cool", legend=False, size=7,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 매매-분양가 GAP 분포")
plt.show()

# %%
#59 매매-분양가 GAP
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_59, x = '호선', y = '매매_분양가gap', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '매매_분양가gap', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("59타입 매매-분양가 GAP 분포")
plt.show()

# %%
#84 매매평균가
fig, axe = plt.subplots(figsize = (15, 6))
sns.boxplot(data = df_group_84, x = '호선', y = '매매_분양가gap', palette="cool",
            order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
sns.swarmplot(data = df_group_59, x = '호선', y = '매매_분양가gap', size=7, color = ".3", linewidth = 0,
             order = ['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '9호선', '수인분당선', '경의중앙선', '우이신설선'])
plt.title("84타입 매매-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 승하차총객수_노선기준 / 승하차총객수_역기준 scatter plot

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '매매평균가', '매매_분양가gap'],
#       dtype='object')

# %%
# 공급금액 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '공급금액', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '공급금액', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '매매평균가', '매매_분양가gap'],
#       dtype='object')

# %%
# 매매가 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매평균가','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '매매평균가', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '매매평균가', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
# 매매-분양가 GAP 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매-분양가 GAP 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '승하차총객수_역기준', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
plt.show()

# %%
# 매매-분양가 GAP 기준_2

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매-분양가 GAP 분포")
sns.scatterplot(x = '승하차총객수_역기준', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 59타입 매매-분양가 GAP 분포")
plt.show()

# %%
# 매매-분양가 GAP 기준_2

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2','전용면적_분류','매매_분양가gap','승하차총객수_노선기준', '승하차총객수_역기준']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '승하차총객수_노선기준', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
sns.scatterplot(x = '승하차총객수_역기준', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 지하철역까지 도보 거리에 따른 분포

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '매매평균가', '매매_분양가gap'],
#       dtype='object')

# %%
# 공급금액 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '공급금액', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '공급금액', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
# 매매평균가 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매평균가','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '매매평균가', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '매매평균가', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
# 매매-분양가 gap 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매-분양가 GAP 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','지하철도보(분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '지하철도보(분)', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 초등학교 등교거리에 따른 분포

# %%
df.loc[df['초등학교거리(도보/분)'] == "단지내", '초등학교거리(도보/분)'] = 2

# %%
df['초등학교거리(도보/분)'].unique()
# Out:
# array(['3', '8', '9', '5', '15', '6', '14', '12', '28', '1', '4', '10',
#        '13', '7', 2, '11', '29', nan], dtype=object)

# %%
# 초등학교거리(도보/분) object -> int로 바꾸기
df['초등학교거리(도보/분)'] = df['초등학교거리(도보/분)'].fillna(-1).astype('int').replace({-1:np.nan})

# %%
# 공급금액 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '공급금액', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '공급금액', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
# 매매가 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매평균가','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '매매평균가', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '매매평균가', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
# 매매-분양가 gap 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매-분양가 GAP 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','초등학교거리(도보/분)']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '초등학교거리(도보/분)', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 총 세대수 에 따른 아파트 가격 분포

# %%
# 공급금액 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '공급금액', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '공급금액', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
# 매매평균가 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매평균가','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '매매평균가', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '매매평균가', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
# 매매_분양가gap 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매_분양가gap 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','세대수']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '세대수', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매_분양가gap 분포")
plt.show()

# %% [markdown]
# ## 중학교 학군에 따른 분포 (학업성취도랑 특목고 진학률?)

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '평균', '특목고 진학률', '상위', '매매평균가', '매매_분양가gap'],
#       dtype='object')

# %%
# 공급금액 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '공급금액', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '공급금액', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
# 매매평균가 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매평균가','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '매매평균가', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 지역별 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '매매평균가', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
df.columns
# Out:
# Index(['아파트명2', '아파트이름', '공급위치', '공급세대', '공급면적', '공급금액', '지역', '주택구분', '분양/임대',
#        '시공사', '입주예정월', '시', '구', '세대수', '소형평수세대수', '중형평수세대수', '대형평수세대수',
#        '특이사항', '인근 지하철 호선수', '지하철역', '호선', '지하철도보(분)', '을지로', '강남',
#        '초등학교거리(도보/분)', '중학교배정학군', '공급면적_2', '전용면적_분류', '매매_2019', '매매_2020',
#        '매매_2021', '매매_2022', '매매_2023', '전세_2019', '전세_2020', '전세_2021',
#        '전세_2022', '전세_2023', '승하차총객수_노선기준', '승하차총객수_역기준', '전세가율_2019',
#        '전세가율_2020', '전세가율_2021', '전세가율_2022', '전세가율_2023', '소형평수비중', '중형평수비중',
#        '대형평수비중', '평균', '특목고 진학률', '상위', '매매평균가', '매매_분양가gap'],
#       dtype='object')

# %%
# 매매_분양가gap 기준

fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 59타입 매매-분양가 GAP 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','평균', '특목고 진학률']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '평균', y = '특목고 진학률', hue = '아파트명2', size = '매매_분양가gap', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 84타입 매매-분양가 GAP 분포")
plt.show()

# %% [markdown]
# ## 호갱노노 기준 중학교 상위

# %%
# 공급금액 분포
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','공급금액','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '공급금액', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 59타입 공급금액 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','공급금액','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '공급금액', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 공급금액 분포")
plt.show()

# %%
# 매매평균가
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류']= '59타입'][['아파트명2','전용면적_분류','매매평균가','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '매매평균가', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 59타입 매매평균가 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매평균가','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '매매평균가', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매평균가 분포")
plt.show()

# %%
# 매매평균가
fig, axe = plt.subplots(1,2, figsize=(12,5))
df_space_group_59 = df.loc[df['전용면적_분류'] == '59타입'][['아파트명2','전용면적_분류','매매_분양가gap','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '매매_분양가gap', hue = '아파트명2',data = df_space_group_59, sizes=(40, 500), alpha=.5, legend = False, ax = axe[0])
axe[0].set_title("서울 59타입 매매-분양가 GAP 분포")
df_space_group_84 = df.loc[df['전용면적_분류'] == '84타입'][['아파트명2', '전용면적_분류','매매_분양가gap','상위']].groupby(['아파트명2', '전용면적_분류']).mean().reset_index()
sns.scatterplot(x = '상위', y = '매매_분양가gap', hue = '아파트명2', data = df_space_group_84, sizes=(40, 500), alpha=.5, legend = False, ax = axe[1])
axe[1].set_title("서울 지역별 84타입 매매-분양가 GAP 분포")
plt.show()
